# %%
# Clone the repository and navigate into it
# !git clone https://github.com/vijaykumargowdakk/mangaproject.git
# %cd mangaproject

# Install Python dependencies
# !pip install -r requirements.txt

# Install necessary system packages
# !apt-get update
# !apt-get install -y ffmpeg espeak libespeak-dev
# Out:
# Cloning into 'mangaproject'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 97 (delta 1), reused 12 (delta 1), pack-reused 79 (from 1)
# Receiving objects: 100% (97/97), 51.20 MiB | 23.97 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/mangaproject
# Collecting pymupdf>=1.24.0 (from -r requirements.txt (line 2))
#   Downloading pymupdf-1.27.1-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: opencv-python>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (4.13.0.92)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: Pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (11.3.0)
# Collecting ollama>=0.2.0 (from -r requirements.txt (line 8))
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.32.4)
# Collecting edge-tts>=6.1.9 (from -r requirements.txt (line 12))
#   Downloading edge_tts-7.2.7-py3-none-any.whl.metadata (5.5 kB)
# Collecting pyttsx3>=2.90 (from -r requirements.txt (line 13))
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydub>=0.25.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.25.1)
# Requirement already satisfied: moviepy>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.0.3)
# Requirement already satisfied: gradio>=4.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (5.50.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (6.0.3)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (4.67.3)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama>=0.2.0->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama>=0.2.0->-r requirements.txt (line 8)) (2.12.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 9)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 9)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 9)) (2026.2.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts>=6.1.9->-r requirements.txt (line 12)) (3.13.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from edge-tts>=6.1.9->-r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts>=6.1.9->-r requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 17)) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 17)) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 17)) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 17)) (0.6.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.133.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (1.5.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (2.2.2)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.0.22)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.15.4)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.31.0->-r requirements.txt (line 20)) (0.41.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio>=4.31.0->-r requirements.txt (line 20)) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio>=4.31.0->-r requirements.txt (line 20)) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts>=6.1.9->-r requirements.txt (line 12)) (1.22.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio>=4.31.0->-r requirements.txt (line 20)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio>=4.31.0->-r requirements.txt (line 20)) (0.0.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama>=0.2.0->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama>=0.2.0->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=4.31.0->-r requirements.txt (line 20)) (3.24.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio>=4.31.0->-r requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.31.0->-r requirements.txt (line 20)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.31.0->-r requirements.txt (line 20)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.31.0->-r requirements.txt (line 20)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama>=0.2.0->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama>=0.2.0->-r requirements.txt (line 8)) (2.41.4)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=4.31.0->-r requirements.txt (line 20)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio>=4.31.0->-r requirements.txt (line 20)) (0.1.2)
# Downloading pymupdf-1.27.1-cp310-abi3-manylinux_2_28_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 81.6 MB/s eta 0:00:00
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading edge_tts-7.2.7-py3-none-any.whl (30 kB)
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Installing collected packages: pyttsx3, pymupdf, ollama, edge-tts
# Successfully installed edge-tts-7.2.7 ollama-0.6.1 pymupdf-1.27.1 pyttsx3-2.99
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,389 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,821 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:14 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# Hit:18 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,877 kB]
# Get:20 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:21 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,924 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,652 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,780 kB]
# Fetched 40.0 MB in 3s (12.3 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak-dev libespeak1 libportaudio2 libsonic0
# 0 upgraded, 6 newly installed, 0 to remove and 102 not upgraded.
# Need to get 1,575 kB of archives.
# After this operation, 3,802 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak-dev amd64 1.48.15+dfsg-3 [193 kB]
# Fetched 1,575 kB in 1s (2,150 kB/s)
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../0-libportaudio2_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package libsonic0:amd64.
# Preparing to unpack .../1-libsonic0_0.2.0-11build1_amd64.deb ...
# Unpacking libsonic0:amd64 (0.2.0-11build1) ...
# Selecting previously unselected package espeak-data:amd64.
# Preparing to unpack .../2-espeak-data_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak-data:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak1:amd64.
# Preparing to unpack .../3-libespeak1_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak1:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package espeak.
# Preparing to unpack .../4-espeak_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak-dev:amd64.
# Preparing to unpack .../5-libespeak-dev_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Setting up libportaudio2:amd64 (19.6.0-1.1) ...
# Setting up libsonic0:amd64 (0.2.0-11build1) ...
# Setting up espeak-data:amd64 (1.48.15+dfsg-3) ...
# Setting up libespeak1:amd64 (1.48.15+dfsg-3) ...
# Setting up espeak (1.48.15+dfsg-3) ...
# Setting up libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link

# %%
# 1. Install the missing 'zstd' extraction tool first
# !apt-get update && apt-get install -y zstd

# 2. Install Ollama
# !curl -fsSL https://ollama.ai/install.sh | sh

# 3. Start Ollama server as a background process
import subprocess
import time

print("Starting Ollama server...")
subprocess.Popen(["ollama", "serve"])

# Give the server a few seconds to fully initialize
time.sleep(5)

# 4. Pull the required AI models
print("Pulling Moondream (Vision Model)...")
# !ollama pull moondream

print("Pulling Mistral:7b (Text Model)...")
# !ollama pull mistral:7b
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 102 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (502 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 122189 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Starting Ollama server...
# Pulling Moondream (Vision Model)...
#
# Pulling Mistral:7b (Text Model)...

# %%
# Launch the Gradio web interface
# !python app.py
# Out:
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://c7c5015c0ab066f91e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Job ID: 34fda197
# Stage 1: Extracting pages from PDF...
#   Extracted 1 page(s)
# Stage 2: Detecting panels...
#   Detected 4 panel(s)
# Stage 3: Analyzing scenes with AI vision model...
